# %%
l=[]
while True:
    c=int(input('''
    1 push element
    2 pop element
    3 peek element
    4 Display stack
    5 Exit
    
    '''
    ))
    
    if c==1:
        n=input("Enter The Value:-");
        l.append(n)
        print(l)
    elif c==2:
        if len(l)==0:
            print("Empty Stack-")
        else:
            del l[0]
            print(p)
            print(l)
    elif c==3:
        if len(l)==0:
            print("Empty Stack-")
        else:
            print("Last Stack Value:-", l[-1])
    elif c==4:
        print("Display queue:", 1)
    elif c==5:
        break;
    else:
        print("Invalid Opt...")
# Out:
#     1 push element
#     2 pop element
#     3 peek element
#     4 Display stack
#     5 Exit
#
#     1
# Enter The Value:-15
# ['15']
#
#     1 push element
#     2 pop element
#     3 peek element
#     4 Display stack
#     5 Exit
#
#     1
# Enter The Value:-25
# ['15', '25']
#
#     1 push element
#     2 pop element
#     3 peek element
#     4 Display stack
#     5 Exit
#
#     1
# Enter The Value:-35
# ['15', '25', '35']
#
#     1 push element
#     2 pop element
#     3 peek element
#     4 Display stack
#     5 Exit
#
#     1
# Enter The Value:-33
# ['15', '25', '35', '33']
#
#     1 push element
#     2 pop element
#     3 peek element
#     4 Display stack
#     5 Exit
#
#     1
# Enter The Value:-75
# ['15', '25', '35', '33', '75']
#
#     1 push element
#     2 pop element
#     3 peek element
#     4 Display stack
#     5 Exit
#
#     4
# Display queue: 1
#
#     1 push element
#     2 pop element
#     3 peek element
#     4 Display stack
#     5 Exit
#
#     4
# Display queue: 1
#
#     1 push element
#     2 pop element
#     3 peek element
#     4 Display stack
#     5 Exit
#
#     1
# Enter The Value:-14
# ['15', '25', '35', '33', '75', '14']
#
#     1 push element
#     2 pop element
#     3 peek element
#     4 Display stack
#     5 Exit
#
#     4
# Display queue: 1
#
#     1 push element
#     2 pop element
#     3 peek element
#     4 Display stack
#     5 Exit
#
#     1
# Enter The Value:-55
# ['15', '25', '35', '33', '75', '14', '55']
#
#     1 push element
#     2 pop element
#     3 peek element
#     4 Display stack
#     5 Exit
#
#     2
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 22
#      20     else:
#      21         del l[0]
# ---> 22         print(p)
#      23         print(l)
#      24 elif c==3:
#
# NameError: name 'p' is not defined

# %%
l=[]
while True:
    c=int(input('''
    1 push element
    2 pop element
    3 peek element
    4 Display element
    5 Exit
    
    '''
    ))
    
    if c==1:
        n=input("Enter The Value:-");
        l.append(n)
        print(l)
    elif c==2:
        if len(l)==0:
            print("Empty Stack-")
        else:
            del l[0]
            print(p)
            print(l)
    elif c==3:
        if len(l)==0:
            print("Empty Stack-")
        else:
            print("Last Stack Value:-", l[-1])
    elif c==4:
        print("Display queue:", 1)
    elif c==5:
        break;
    else:
        print("Invalid Opt...")
# Out:
#     1 push element
#     2 pop element
#     3 peek element
#     4 Display element
#     5 Exit
#
#     1
# Enter The Value:-22
# ['22']
#
#     1 push element
#     2 pop element
#     3 peek element
#     4 Display element
#     5 Exit
#
#     1
# Enter The Value:-55
# ['22', '55']
#
#     1 push element
#     2 pop element
#     3 peek element
#     4 Display element
#     5 Exit
#
#     1
# Enter The Value:-66
# ['22', '55', '66']
#
#     1 push element
#     2 pop element
#     3 peek element
#     4 Display element
#     5 Exit
#
#     1
# Enter The Value:-77
# ['22', '55', '66', '77']
#
#     1 push element
#     2 pop element
#     3 peek element
#     4 Display element
#     5 Exit
#
#     1
# Enter The Value:-99
# ['22', '55', '66', '77', '99']
#
#     1 push element
#     2 pop element
#     3 peek element
#     4 Display element
#     5 Exit
#
#     2
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 22
#      20     else:
#      21         del l[0]
# ---> 22         print(p)
#      23         print(l)
#      24 elif c==3:
#
# NameError: name 'p' is not defined
