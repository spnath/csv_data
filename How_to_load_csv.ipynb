# %%
# import pandas as pd
a=pd.read_csv('D:\DA-2023\Kaggle datasets\extract\Methane_final.csv')
a
# Out:
#       Unnamed: 0  region  country      emissions         type  \
# 0              0  Africa  Algeria     257.611206  Agriculture
# 1              1  Africa  Algeria       0.052000       Energy
# 2              2  Africa  Algeria     130.798996       Energy
# 3              3  Africa  Algeria      69.741898       Energy
# 4              4  Africa  Algeria     213.987000       Energy
# ...          ...     ...      ...            ...          ...
# 1543        1543   World    World    3102.500000       Energy
# 1544        1544   World    World   30296.500000       Energy
# 1545        1545   World    World  133350.984375       Energy
# 1546        1546   World    World    9737.874023        Other
# 1547        1547   World    World   70758.710938        Waste
#
#                                              segment    reason   baseYear  \
# 0                                              Total       All  2019-2021
# ...

# %%
b=pd.read_csv('D:\DA-2023\Kaggle datasets\extract\Methane_final.csv',nrows=101)
b
# Out:
#      Unnamed: 0  region        country   emissions         type  \
# 0             0  Africa        Algeria  257.611206  Agriculture
# 1             1  Africa        Algeria    0.052000       Energy
# 2             2  Africa        Algeria  130.798996       Energy
# 3             3  Africa        Algeria   69.741898       Energy
# 4             4  Africa        Algeria  213.987000       Energy
# ..          ...     ...            ...         ...          ...
# 96           96  Africa  Cote d'Ivoire    3.062550       Energy
# 97           97  Africa  Cote d'Ivoire    5.116020       Energy
# 98           98  Africa  Cote d'Ivoire   11.100700       Energy
# 99           99  Africa  Cote d'Ivoire    1.584080       Energy
# 100         100  Africa  Cote d'Ivoire    0.803796       Energy
#
#                               segment    reason   baseYear  \
# 0                               Total       All  2019-2021
# 1                           Bioenergy       All       2022
# ...

# %%
c=pd.read_csv('D:\DA-2023\Kaggle datasets\extract\Methane_final.csv',usecols=[0,2])
c
# Out:
#       Unnamed: 0  country
# 0              0  Algeria
# 1              1  Algeria
# 2              2  Algeria
# 3              3  Algeria
# 4              4  Algeria
# ...          ...      ...
# 1543        1543    World
# 1544        1544    World
# 1545        1545    World
# 1546        1546    World
# 1547        1547    World
#
# [1548 rows x 2 columns]

# %%
c_skip=pd.read_csv('D:\DA-2023\Kaggle datasets\extract\Methane_final.csv',skiprows=[8,9])
c_skip
# Out:
#       Unnamed: 0  region  country      emissions         type  \
# 0              0  Africa  Algeria     257.611206  Agriculture
# 1              1  Africa  Algeria       0.052000       Energy
# 2              2  Africa  Algeria     130.798996       Energy
# 3              3  Africa  Algeria      69.741898       Energy
# 4              4  Africa  Algeria     213.987000       Energy
# ...          ...     ...      ...            ...          ...
# 1541        1543   World    World    3102.500000       Energy
# 1542        1544   World    World   30296.500000       Energy
# 1543        1545   World    World  133350.984375       Energy
# 1544        1546   World    World    9737.874023        Other
# 1545        1547   World    World   70758.710938        Waste
#
#                                              segment    reason   baseYear  \
# 0                                              Total       All  2019-2021
# ...

# %%
index=pd.read_csv('D:\DA-2023\Kaggle datasets\extract\Methane_final.csv',index_col='notes')
index
# Out:
#                                                     Unnamed: 0  region  \
# notes
# Average based on United Nations Framework Conve...           0  Africa
# Estimates from end-uses are for 2020 or 2021 (I...           1  Africa
# Not available                                                2  Africa
# Not available                                                3  Africa
# Not available                                                4  Africa
# ...                                                        ...     ...
# Not available                                             1543   World
# Not available                                             1544   World
# Estimates from end-uses are for 2020 or 2021 (I...        1545   World
# Average based on United Nations Framework Conve...        1546   World
# Average based on United Nations Framework Conve...        1547   World
#
#                                                     country      emissions  \
# notes
# ...

# %%
header=pd.read_csv('D:\DA-2023\Kaggle datasets\extract\Methane_final.csv',header=2)
header
# Out:
#          1  Africa  Algeria  0.0520000010728836  Energy  \
# 0        2  Africa  Algeria          130.798996  Energy
# 1        3  Africa  Algeria           69.741898  Energy
# 2        4  Africa  Algeria          213.987000  Energy
# 3        5  Africa  Algeria          464.308014  Energy
# 4        6  Africa  Algeria          469.786987  Energy
# ...    ...     ...      ...                 ...     ...
# 1541  1543   World    World         3102.500000  Energy
# 1542  1544   World    World        30296.500000  Energy
# 1543  1545   World    World       133350.984375  Energy
# 1544  1546   World    World         9737.874023   Other
# 1545  1547   World    World        70758.710938   Waste
#
#                                            Bioenergy       All       2022  \
# 0                   Gas pipelines and LNG facilities  Fugitive       2022
# 1                   Gas pipelines and LNG facilities    Vented       2022
# ...

# %%
col=pd.read_csv('D:\DA-2023\Kaggle datasets\extract\Methane_final.csv',names=['col1','col2','col3','col4','col5'])
col
# Out:
#                                                  col1  \
# NaN    region country emissions                  type
# 0.0    Africa Algeria 257.6112060546875   Agriculture
# 1.0    Africa Algeria 0.0520000010728836       Energy
# 2.0    Africa Algeria 130.7989959716797        Energy
# 3.0    Africa Algeria 69.74189758300781        Energy
# ...                                               ...
# 1543.0 World  World   3102.5                   Energy
# 1544.0 World  World   30296.5                  Energy
# 1545.0 World  World   133350.984375            Energy
# 1546.0 World  World   9737.8740234375           Other
# 1547.0 World  World   70758.7109375             Waste
#
#                                                                                     col2  \
# NaN    region country emissions                                                  segment
# 0.0    Africa Algeria 257.6112060546875                                            Total
# ...
