# %%
import matplotlib.pyplot as plt
import numpy as np
y=np.array([10,30,40,50,60,70])
plt.plot(y)

# %%
import matplotlib.pyplot as plt
import numpy as np
y=np.array([10,30,40,50,60,70])
plt.xlable="Suku"
plt.plot(y)
plt.show()
